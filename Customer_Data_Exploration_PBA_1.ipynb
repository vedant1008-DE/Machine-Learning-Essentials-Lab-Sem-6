# %% [markdown]
# <a href="https://colab.research.google.com/github/vedant1008-DE/Machine-Learning-Essentials-Lab-Sem-6/blob/main/Customer_Data_Exploration_PBA_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Step 2: Load the Dataset

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0970cf49-7584-493e-847a-13039f0b33e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0970cf49-7584-493e-847a-13039f0b33e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("OnlineRetail.csv", encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0  INV10000    84406B      CREAM CUPID HEARTS COAT HANGER         6
# 1  INV10001    85123A  WHITE HANGING HEART T-LIGHT HOLDER        19
# 2  INV10002     22752        SET 7 BABUSHKA NESTING BOXES        16
# 3  INV10003    85123A  WHITE HANGING HEART T-LIGHT HOLDER        14
# 4  INV10004     21730   GLASS STAR FROSTED T-LIGHT HOLDER         1
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2011-05-31 00:00:00       4.77       12887     Netherlands
# 1  2011-10-13 00:00:00       1.55       12086           Spain
# 2  2011-09-18 00:00:00      19.93       12211           Spain
# 3  2011-03-12 00:00:00       7.70       12219  United Kingdom
# 4  2011-08-25 00:00:00      23.35       12836           Spain

# %%
df = pd.read_csv("OnlineRetail.csv", encoding='ISO-8859-1')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0  INV10000    84406B      CREAM CUPID HEARTS COAT HANGER         6
# 1  INV10001    85123A  WHITE HANGING HEART T-LIGHT HOLDER        19
# 2  INV10002     22752        SET 7 BABUSHKA NESTING BOXES        16
# 3  INV10003    85123A  WHITE HANGING HEART T-LIGHT HOLDER        14
# 4  INV10004     21730   GLASS STAR FROSTED T-LIGHT HOLDER         1
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2011-05-31 00:00:00       4.77       12887     Netherlands
# 1  2011-10-13 00:00:00       1.55       12086           Spain
# 2  2011-09-18 00:00:00      19.93       12211           Spain
# 3  2011-03-12 00:00:00       7.70       12219  United Kingdom
# 4  2011-08-25 00:00:00      23.35       12836           Spain

# %% [markdown]
# Step 3: Inspect Dataset Structure

# %%
df.info()
df.describe()
df.shape
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    120 non-null    object
#  1   StockCode    120 non-null    object
#  2   Description  120 non-null    object
#  3   Quantity     120 non-null    int64
#  4   InvoiceDate  120 non-null    object
#  5   UnitPrice    120 non-null    float64
#  6   CustomerID   120 non-null    int64
#  7   Country      120 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 7.6+ KB
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# Step 4: Handle Missing Values

# %%
df = df.dropna(subset=['CustomerID'])

# %%
df['Description'] = df['Description'].fillna('Unknown')

# %% [markdown]
# Step 5: Remove Duplicate Records

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (120, 8)

# %% [markdown]
# Step 6: Explore Customer Purchasing Behavior

# %%
top_products = df.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)
print(top_products)
# Out:
# Description
# CREAM CUPID HEARTS COAT HANGER         268
# SET 7 BABUSHKA NESTING BOXES           220
# RED WOOLLY HOTTIE WHITE HEART          205
# WHITE HANGING HEART T-LIGHT HOLDER     195
# GLASS STAR FROSTED T-LIGHT HOLDER      171
# KNITTED UNION FLAG HOT WATER BOTTLE    140
# WHITE METAL LANTERN                     54
# Name: Quantity, dtype: int64

# %% [markdown]
# Step 7: Visualization – Distribution of Purchase Quantity

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Quantity'], bins=50, kde=True)
plt.title("Distribution of Purchase Quantity")
plt.xlabel("Quantity")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Step 8: Visualization – Top Selling Products

# %%
top_products.plot(kind='bar', figsize=(10,5))
plt.title("Top Selling Products")
plt.xlabel("Product")
plt.ylabel("Total Quantity Sold")
plt.show()
